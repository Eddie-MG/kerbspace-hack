# %%
import requests 
import pandas as pd
import numpy as np
import cv2
# from pyproj import Transformer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-89f35644ba27> in <module>
#       3 import numpy as np
#       4 import cv2
# ----> 5 from pyproj import Transformer
#
# ModuleNotFoundError: No module named 'pyproj'

# %%
el_requesto = requests.get('https://fordkerbhack.azure-api.net/features?viewport=51.5535663,-0.1887717,51.5589623,-0.1788357', headers={'Ocp-Apim-Subscription-Key':"fb692dfd71834bc5b40d2bf3aef7be2c"})

# %%
kerb_json = el_requesto.json()

# %%
kerb_json['features'][0]['re']
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18142974423865305, 51.55577586685526],
#     [-0.18142613923823453, 51.555877757353365]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/61E25425-C048-4AD9-A0C3-B44DEE6C8BFA?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '20:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': 'd61447df-a967-08f8-eedd-26bf31893e6d',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 34.741547422598984,
#     'shstLocationEnd': 46.07418133364166,
#     'objectId': '0008da2d-2b16-4087-a1ba-d958348594ce',
#     'streetName': '1a Frognal Gardens, London, NW3 6, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.17980040235097644, 51.55815224558373],
#     [-0.17998266165281965, 51.55809224727685]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/599EDCF6-B656-45F5-940A-DB0FBFFC74F3?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '20:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': 'ca8f3d0e-fbb4-d946-9255-88106e788450',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 14.920893592996961,
#     'shstLocationEnd': 29.72237063033564,
#     'objectId': '003fbd52-4dcc-44cd-96d1-271f70fa04ae',
#     'streetName': 'Holly Bush Hill, London, NW3 6, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.17998224207204225, 51.55552510234325],
#     [-0.17978008016289715, 51.555538262756706]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/1653A489-EF48-4A4F-9143-5D501A9ACC77?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '22:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '5e12e112-58d9-c789-07aa-2ab1d684f2a4',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 24.082951618781305,
#     'shstLocationEnd': 38.13607446993689,
#     'objectId': '05876ac2-b039-4117-a386-3b49072e83ae',
#     'streetName': '10 Church Row, London, NW3 6UT, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.17921589696779772, 51.55554138065621],
#     [-0.17975200063927396, 51.55547438142838]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/9BE13C50-BA97-4647-B039-8CA0C2B172D3?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '22:00'}}],
#      'priority': 4}],
#    'location': {'sideOfStreet': 'left',
#     'shstLocationStart': 0.0,
#     'shstLocationEnd': 0.0,
#     'objectId': '07c9308d-6f43-4b2c-9c37-a72d3a8a8d60',
#     'streetName': '22 Church Row, London, NW3 6UP, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18187432454857552, 51.55540598353928],
#     [-0.18215058682279703, 51.55536425063709]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/44F15A7D-81EE-4D5A-B08D-882F10C6EE3F?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '22:00'}}],
#      'priority': 4}],
#    'location': {'sideOfStreet': 'left',
#     'shstLocationStart': 0.0,
#     'shstLocationEnd': 0.0,
#     'objectId': '080ccbb4-cb73-4311-b4d5-e7f3cf1de33f',
#     'streetName': 'NW3 6UU, London, England, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.1855216472788357, 51.556212020826536],
#     [-0.1858055815607452, 51.556313142793655]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/FC21CE48-B2EC-4081-9219-793A38245502?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '19:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '5ef761c0-4a8f-c44c-8c95-ddd99151c705',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 8.653975173205737,
#     'shstLocationEnd': 31.27610353221185,
#     'objectId': '081dbb05-3273-4d8c-9e48-b7d56b2bf669',
#     'streetName': '27 Redington Road, London, NW3 7QY, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18277214889248136, 51.55475737951572],
#     [-0.18280867739906279, 51.55485826380173]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/3F53EA56-6419-472E-AA5C-371C7A0E5549?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '19:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '8ac0946f-78dd-d57c-cb99-ebf4308a8088',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 32.19378670433002,
#     'shstLocationEnd': 43.69240015439816,
#     'objectId': '0b93b3dd-4d00-4362-a1c3-43e483551bd5',
#     'streetName': 'Frognal, London, NW3 6, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18139682783145103, 51.558884185092005],
#     [-0.18127535086131052, 51.55881314167942]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/1284BAEE-04D7-4A5A-A94D-0C290896195B?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '20:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '4e22cc1f-3eb7-16b2-ce23-c6016beea50a',
#     'sideOfStreet': 'left',
#     'shstLocationStart':
sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '19:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '147674e3-e495-e5f4-7a9e-2b26cd4dd5c4',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 203.0926554213862,
#     'shstLocationEnd': 239.38126158599366,
#     'objectId': '3a04e598-c325-4e19-9623-29161eb68e8f',
#     'streetName': 'Chesterford Gardens, London, NW3 7, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18678113486003678, 51.55491363483147],
#     [-0.18670654476562815, 51.554875626218184]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/BF860713-EC06-44BB-B46D-1E4F157D12E0?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-S']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '18:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '3beb3b1e-081a-09a1-a627-c91d0e133d65',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 164.9469622866756,
#     'shstLocationEnd': 171.55321325855226,
#     'objectId': '3b1ed5f8-d042-42af-b564-734e32e01385',
#     'streetName': 'NW3 7DH, London, England, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18843545161685804, 51.555963559360315],
#     [-0.18895430072495767, 51.55571906159196]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/8463CDEB-6109-4386-8C51-70DE112938F5?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-S']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '18:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '86e7188e-43fd-a4ea-39bb-f719eaadc926',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 9.985396374090527,
#     'shstLocationEnd': 54.99450137194895,
#     'objectId': '3b258288-01e2-4e2d-a0dd-2725eff94596',
#     'streetName': '17 Oakhill Avenue, London, NW3 7RD, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18459769634557743, 51.55517194326644],
#     [-0.18431724751124465, 51.55471156471367]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/770D5B28-38BB-409B-B3BA-388B2C483260?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '19:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '147674e3-e495-e5f4-7a9e-2b26cd4dd5c4',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 138.53716223371433,
#     'shstLocationEnd': 193.0773779542044,
#     'objectId': '3ba94caa-80fd-43c5-a43a-e66f26adf256',
#     'streetName': '15 Chesterford Gardens, London, NW3 7DD, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18147184637397842, 51.55794152120842],
#     [-0.18140188168027302, 51.558042899989374],
#     [-0.18125960145905318, 51.5584170209456]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/3C6BECDF-AE6C-40E3-B2E1-BD8B6AE382EC?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'Paid',
#       'maxStay': 240,
#       'noReturn': 0,
#       'payment': True},
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '18:00'}}],
#      'payment': {'rates': [{'fees': [2.55],
#         'durations': [60],
#         'timeSpans': [{'daysOfWeek': {'days': ['mo',
#             'tu',
#             'we',
#             'th',
#             'fr',
#             'sa']},
#           'timesOfDay': {'from': '09:00', 'to': '18:00'}}]}],
#       'methods': ['phone', 'digital'],
#       'forms': [],
#       'operator': 'RINGGO',
#       'phone': '020 7125 0039',
#       'deviceIds': []},
#      'priority': 4}],
#    'location': {'shstRefId': '7f9e7607-757f-4999-4973-4ec07cc2f10d',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 52.54122025614689,
#     'shstLocationEnd': 107.89961866639257,
#     'objectId': '3ee280ff-8d42-4b06-8e8d-bb3253c2a2e9',
#     'streetName': '109 Frognal, London, NW3 6XR, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18142208932583354, 51.55599222269148],
#     [-0.18141321774969915, 51.556242965883264]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/080BB10D-13BE-4C28-AF45-C050B8C9BC3C?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '20:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': 'd61447df-a967-08f8-eedd-26bf31893e6d',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 58.80540464185677,
#     'shstLocationEnd': 86.69338605069257,
#     'objectId': '3f0a2453-9576-4d51-81b9-bd668e851846',
#     'streetName': 'NW3 6UY, London, England, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.1794678690098247, 51.558610181644106],
#     [-0.1795037604147557, 51.55839639800765],
#     [-0.1795894169323099, 51.558220007916084]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/BDC14700-B790-4908-B570-DB828B70F2A6?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '20:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': 'b41627d6-0322-28c0-5c49-75d58f6c1134',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 100.92474344566315,
#     'shstLocationEnd': 145.13329087105885,
#     'objectId': '4082ae7e-e727-457d-aeed-68d112e84419',
#     'streetName': 'NW3 6SN, London, England, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0

#     'sideOfStreet': 'left',
#     'shstLocationStart': 64.61400520124411,
#     'shstLocationEnd': 83.15030966949239,
#     'objectId': 'ec5988c2-3f06-4560-85fb-d4bbbd08db54',
#     'streetName': '9 Ellerdale Road, London, NW3 6, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18058369776044356, 51.55705888799743],
#     [-0.1805980570478881, 51.55692110382932]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/1575DBA0-3C6A-4C70-B055-68FA31D30525?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '20:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '53f44b05-b6f8-6848-7fa3-82a80e32d6ed',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 37.508502795630655,
#     'shstLocationEnd': 52.850508547882306,
#     'objectId': 'edc10462-9cc7-4941-844a-082568304432',
#     'streetName': 'NW3 6QU, London, England, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18778241995763437, 51.5540058121805],
#     [-0.1880572247851047, 51.554144909604226]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/88B690DC-4A6B-4173-B082-146007FFA346?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-W']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '18:00'}}],
#      'priority': 4},
#     {'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-S']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '18:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': 'ecf51cfc-a4d8-7586-c434-43d6cc9e0f38',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 87.42528557095704,
#     'shstLocationEnd': 111.92477515402842,
#     'objectId': 'f14a94ec-323e-456c-8af5-f45ba9b2b314',
#     'streetName': 'Bracknell Gardens, London, NW3 7, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18031488071373852, 51.5581879721047],
#     [-0.18037809363610688, 51.55822702881865],
#     [-0.18094660050782949, 51.55857563723274],
#     [-0.18116166978999637, 51.55860529569452]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/C7CA4623-E117-429F-B918-E972D8F06421?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '20:00'}}],
#      'priority': 4}],
#    'location': {'sideOfStreet': 'left',
#     'shstLocationStart': 0.0,
#     'shstLocationEnd': 0.0,
#     'objectId': 'f436a342-dcaa-46dd-8982-7ea409617b1b',
#     'streetName': 'Frognal Rise, London, NW3 6, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.1866703225237266, 51.557155575731855],
#     [-0.1865563311821656, 51.55705438242517]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/43D1C552-418A-41FB-B115-61833BDA8691?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '19:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': '8b0cf99e-2985-bb83-6675-98acdcb0852a',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 124.66554297370598,
#     'shstLocationEnd': 138.40288838819535,
#     'objectId': 'f651ef06-f75b-4b77-8be7-eec737832b0f',
#     'streetName': '22 Redington Road, London, NW3 7, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18618375234353432, 51.554571055319755],
#     [-0.1861510489685582, 51.55454643216258]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/9A77436E-0426-4613-94D9-20E68D11B785?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-S']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '18:00'}}],
#      'priority': 4}],
#    'location': {'sideOfStreet': 'left',
#     'shstLocationStart': 0.0,
#     'shstLocationEnd': 0.0,
#     'objectId': 'fa95eb2d-f452-4bdd-b60f-3a0ed4c391cc',
#     'streetName': 'Greenaway Gardens, London, NW3 7, United Kingdom'}}},
#  {'type': 'Feature',
#   'geometry': {'type': 'LineString',
#    'coordinates': [[-0.18523816238134264, 51.554005965281306],
#     [-0.18508239032196735, 51.55401980176745]]},
#   'properties': {'images': ['https://fordspacesprod.blob.core.windows.net/images/CD26BB54-9A2F-4404-9DAA-172F9DF9FCD5?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'],
#    'regulations': [{'rule': {'activity': 'parking',
#       'reason': 'residentpermit',
#       'maxStay': 0,
#       'noReturn': 0,
#       'payment': False},
#      'userClasses': [{'classes': ['ResidentPermit CA-H']}],
#      'timeSpans': [{'daysOfWeek': {'days': ['mo',
#          'tu',
#          'we',
#          'th',
#          'fr',
#          'sa']},
#        'timesOfDay': {'from': '09:00', 'to': '19:00'}}],
#      'priority': 4}],
#    'location': {'shstRefId': 'f32e9550-d57c-5d95-7286-f4a5f05f08fd',
#     'sideOfStreet': 'left',
#     'shstLocationStart': 26.530502884447547,
#     'shstLocationEnd': 37.4097226804364,
#     'objectId': 'ff1d52df-9a61-4b17-86cc-6f10fc0ed434',
#     'streetName': '32 Frognal Lane, London, NW3 7DT, United Kingdom'}}}]

# %%
from imageai.Detection import ObjectDetection

import os



execution_path = os.getcwd()



detector = ObjectDetection()

detector.setModelTypeAsRetinaNet()

detector.setModelPath( os.path.join(execution_path , "resnet50_coco_best_v2.0.1.h5"))

detector.loadModel()

detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , r"Upper_St_Theberton_St_2019-11-11\2019-11-11\2019-11-11@14_15GMT.jpg"), output_image_path=os.path.join(execution_path , "imagenew.jpg"))
# Out:
# tracking <tf.Variable 'Variable_15:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_16:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_17:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_18:0' shape=(9, 4) dtype=float32> anchors
# tracking <tf.Variable 'Variable_19:0' shape=(9, 4) dtype=float32> anchors
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\imageai\Detection\__init__.py in detectObjectsFromImage(self, input_image, output_image_path, input_type, output_type, extract_detected_objects, minimum_percentage_probability, display_percentage_probability, display_object_name, thread_safe)
#     325                     if (input_type == "file"):
# --> 326                         image = read_image_bgr(input_image)
#     327                     elif (input_type == "array"):
#
# ~\Anaconda3\lib\site-packages\imageai\Detection\keras_retinanet\utils\image.py in read_image_bgr(path)
#      28 def read_image_bgr(path):
# ---> 29     image = np.asarray(Image.open(path).convert('RGB'))
#      30     return image[:, :, ::-1].copy()
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Computing\\Hackathon\\ford-hack\\https://fordspacesprod.blob.core.windows.net/images/61E25425-C048-4AD9-A0C3-B44DEE6C8BFA?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-460fa6b68ad5> in <module>
#      15 detector.loadModel()
#      16
# ---> 17 detections = detector.detectObjectsFromImage(input_image=os.path.join(execution_path , "https://fordspacesprod.blob.core.windows.net/images/61E25425-C048-4AD9-A0C3-B44DEE6C8BFA?sv=2018-03-28&ss=bfqt&srt=sco&sp=rwdlacup&se=2019-12-31T01:15:21Z&st=2019-07-04T16:15:21Z&spr=https&sig=XM7fTquAaxv%2Fofax7YmxjWpVE%2FndpYYBt1wtmidhlmM%3D"), output_image_path=os.path.join(execution_path , "imagenew.jpg"))
#
# ~\Anaconda3\lib\site-packages\imageai\Detection\__init__.py in detectObjectsFromImage(self, input_image, output_image_path, input_type, output_type, extract_detected_objects, minimum_percentage_probability, display_percentage_probability, display_object_name, thread_safe)
#     542             except:
#     543                 raise ValueError(
# --> 544                     "Ensure you specified correct input image, input type, output type and/or output image path ")
#     545
#     546     def CustomObjects(self, person=False, bicycle=False, car=False, motorcycle=False, airplane=False,
#
# ValueError: Ensure you specified correct input image, input type, output type and/or output image path

# %%
for eachObject in detections:
    print(eachObject)
# Out:
# {'name': 'car', 'percentage_probability': 52.85045504570007, 'box_points': [156, 9, 174, 27]}
# {'name': 'person', 'percentage_probability': 60.029393434524536, 'box_points': [88, 77, 97, 105]}
# {'name': 'person', 'percentage_probability': 58.618372678756714, 'box_points': [75, 80, 86, 108]}
# {'name': 'person', 'percentage_probability': 51.33609175682068, 'box_points': [63, 84, 74, 113]}
# {'name': 'car', 'percentage_probability': 52.01278328895569, 'box_points': [140, 35, 165, 55]}
# {'name': 'car', 'percentage_probability': 81.60916566848755, 'box_points': [222, 36, 245, 56]}
# {'name': 'car', 'percentage_probability': 60.60898303985596, 'box_points': [141, 52, 171, 90]}
# {'name': 'car', 'percentage_probability': 64.5590603351593, 'box_points': [94, 116, 150, 171]}
# {'name': 'truck', 'percentage_probability': 69.25075054168701, 'box_points': [31, 136, 132, 237]}
# {'name': 'bus', 'percentage_probability': 59.40718650817871, 'box_points': [185, 80, 318, 284]}

# %%
quad_coords = {

    "lonlat": np.array([

        [6.602018, 52.036769], # Third lampost top right

        [6.603227, 52.036181], # Corner of white rumble strip top left

        [6.603638, 52.036558], # Corner of rectangular road marking bottom left

        [6.603560, 52.036730] # Corner of dashed line bottom right

    ]),

    "pixel": np.array([

        [1200, 278], # Third lampost top right

        [87, 328], # Corner of white rumble strip top left

        [36, 583], # Corner of rectangular road marking bottom left

        [1205, 698] # Corner of dashed line bottom right

    ])

}

# %%
class PixelMapper(object):

    """

    Create an object for converting pixels to geographic coordinates,

    using four points with known locations which form a quadrilteral in both planes

    Parameters

    ----------

    pixel_array : (4,2) shape numpy array

        The (x,y) pixel coordinates corresponding to the top left, top right, bottom right, bottom left

        pixels of the known region

    lonlat_array : (4,2) shape numpy array

        The (lon, lat) coordinates corresponding to the top left, top right, bottom right, bottom left

        pixels of the known region

    """

    def __init__(self, pixel_array, lonlat_array):

        assert pixel_array.shape==(4,2), "Need (4,2) input array"

        assert lonlat_array.shape==(4,2), "Need (4,2) input array"

        self.M = cv2.getPerspectiveTransform(np.float32(pixel_array),np.float32(lonlat_array))

        self.invM = cv2.getPerspectiveTransform(np.float32(lonlat_array),np.float32(pixel_array))

        

    def pixel_to_lonlat(self, pixel):

        """

        Convert a set of pixel coordinates to lon-lat coordinates

        Parameters

        ----------

        pixel : (N,2) numpy array or (x,y) tuple

            The (x,y) pixel coordinates to be converted

        Returns

        -------

        (N,2) numpy array

            The corresponding (lon, lat) coordinates

        """

        if type(pixel) != np.ndarray:

            pixel = np.array(pixel).reshape(1,2)

        assert pixel.shape[1]==2, "Need (N,2) input array" 

        pixel = np.concatenate([pixel, np.ones((pixel.shape[0],1))], axis=1)

        lonlat = np.dot(self.M,pixel.T)

        

        return (lonlat[:2,:]/lonlat[2,:]).T

    

    def lonlat_to_pixel(self, lonlat):

        """

        Convert a set of lon-lat coordinates to pixel coordinates

        Parameters

        ----------

        lonlat : (N,2) numpy array or (x,y) tuple

            The (lon,lat) coordinates to be converted

        Returns

        -------

        (N,2) numpy array

            The corresponding (x, y) pixel coordinates

        """

        if type(lonlat) != np.ndarray:

            lonlat = np.array(lonlat).reshape(1,2)

        assert lonlat.shape[1]==2, "Need (N,2) input array" 

        lonlat = np.concatenate([lonlat, np.ones((lonlat.shape[0],1))], axis=1)

        pixel = np.dot(self.invM,lonlat.T)

        

        return (pixel[:2,:]/pixel[2,:]).T

# %%
pm = PixelMapper(quad_coords["pixel"], quad_coords["lonlat"])



uv_0 = (350, 370) # Top left give way sign in frame

lonlat_0 = pm.pixel_to_lonlat(uv_0)



lonlat_1 = (6.603361, 52.036639) # Center of the roundabout on googlemaps

uv_1 = pm.lonlat_to_pixel(lonlat_1)

# %%
transformer = Transformer.from_crs(4326, 28992, always_xy=True) # Enforce lon,lat order



lonlat_1 = (6.603361, 52.036639) # Center of the roundabout on googlemaps

xy_1 = transformer.transform(*lonlat_1)
